# %% [markdown]
# # **SVM - Kernel comparison**

# %% [markdown]
# ## Kernel interpretation

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from PIL import Image
from sklearn import svm
from sklearn.datasets import make_gaussian_quantiles

# %%
# Generar datos
X, Y = make_gaussian_quantiles(cov=3,
                                 n_samples=400, n_features=2,
                                 n_classes=2, random_state=1)

# Crear figura y eje 3D
fig = plt.figure()
X[Y == 0] = X[Y == 0]*0.5

_,ax = plt.subplots(figsize = (5,4))
# Graficar datos
ax.scatter(X[:, 0], X[:, 1], s=10, c=Y, cmap=plt.cm.Paired)

# %%
z = X[:,0]**2 + X[:,1]**2
print(z.shape)
# Out:
# (400,)

# %%
f,_ = plt.subplots(figsize=(5,4))
fig = plt.figure()
ax = f.add_subplot(projection='3d')

# Configurar vista
ax.view_init(10, 45)
ax.scatter3D(X[:, 0], X[:, 1], z, s=10, c=Y, alpha=0.8, cmap=plt.cm.Paired)
# Ajustar layout
plt.tight_layout()
ax.set_zlim(0,5)
ax.set_xlabel('h')
ax.set_ylabel('v')


# Crear el grid de las fronteras de decisión
h_grid, v_grid = np.meshgrid(np.linspace(-4,4, 50), np.linspace(-4, 3, 50))
z_grid = np.ones(h_grid.shape) * 1.5
ax.plot_surface(h_grid, v_grid, z_grid, alpha = 0.5)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from PIL import Image
from sklearn import svm
from sklearn.datasets import make_gaussian_quantiles

# Generar datos
X, Y = make_gaussian_quantiles(cov=2,
                                 n_samples=400, n_features=2,
                                 n_classes=2, random_state=1)

# Crear figura y eje 3D
fig = plt.figure()
X[Y == 0] = X[Y == 0]*0.5

_,ax = plt.subplots(figsize = (5,4))
# Graficar datos
ax.scatter(X[:, 0], X[:, 1], s=10, c=Y, cmap=plt.cm.Paired)

# Configurar vista
# ax.view_init(90, 0)
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_title("Scatter plot")

# Ajustar layout
plt.tight_layout()

# Mostrar gráfico
plt.show()

# Save all figs
import os
from PIL import Image

# Save a gif
all_images = []
for i in range(360):
    # Apply rotation
    ax.clear()
    ax.scatter(X[:, 0], X[:, 1], s=10, c=Y, cmap=plt.cm.Paired)
    ax.set_xlabel("X-axis")
    ax.set_ylabel("Y-axis")
    ax.set_title("Scatter plot")
    all_images.append(fig)

image = Image.fromarray(np.asarray(fig.canvas.buffer))
image.save("kernel_.gif", save_all=True, append_images=all_images, duration=200, loop=0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-1640fe7d54be> in <cell line: 40>()
#      42
#      43     # Guardar la figura actual
# ---> 44     image_array = np.frombuffer(fig.canvas.tostring_rgb(), dtype='uint8')
#      45     image_array = image_array.reshape(fig.canvas.get_width_height()[::-1] + (3,))
#      46     all_images.append(Image.fromarray(image_array))
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backends/backend_agg.py in tostring_rgb(self)
#     422         to update the renderer for any subsequent changes to the Figure.
#     423         """
# --> 424         return self.renderer.tostring_rgb()
#     425
#     426     def tostring_argb(self):
#
# AttributeError: 'FigureCanvasAgg' object has no attribute 'renderer'

# %%
# Sve all figs
for angle in range (0, 91, 5):
  f, _ = plt.subplots(figsize = (8,7))
  ax = f.add_subplot(projection='3d')
  ax.view_init(angle, 45)
  ax.scatter3D(X[:, 0], X[:, 1], z,alpha=0.8, cmap="Paired")
  ax.plot_surface(h_grid, v_grid, z_grid, alpha=0.5)
  ax.set_zlim(0, 5)
  plt.tight_layout()
  plt.savefig("imgs/{0}.png".format(angle))
  plt.close(), plt.clf()
# Out:
# <ipython-input-63-f74746896c63>:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter3D(X[:, 0], X[:, 1], z,alpha=0.8, cmap="Paired")

# %%
import os
from PIL import Image
from natsort import natsorted, ns

list_images = []
# Save a gif
#print(natsorted(os.listdir('imgs/')))
for img in natsorted (os.listdir('imgs/')):
  image = Image.open('imgs/' + img)
  list_images.append(image)
image.save("animation.gif", save_all=True, append_images=list_images, duration=200, loop=0)

# %% [markdown]
# ## SVM

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import make_classification

# %%
# we create 100 separable points
X, Y = make_classification(n_samples = _ , n_features=2, n_redundant=0, n_informative=2, n_clusters_per_class=2, random_state=2)
plt.scatter( _ , _ , c = _ , s = _, cmap=plt.cm.Paired)

# %%
kernels = ['linear', 'poly', 'rbf']

_, axes = plt.subplots(1,3, figsize = (20,5))

# fit the model
for _ :
    #
    clf = svm.SVC(kernel = _ , gamma = 1)
    clf.fit( _ , _ )

    x_min, x_max = _ , _
    y_min, y_max = _ , _

    x_dim, y_dim = np.meshgrid(np.arange( _ , _ , 0.01), np.arange( _ , _ , 0.01))
    predictions = clf.predict(np.c_[x_dim.ravel(), y_dim.ravel()])

    predictions = predictions.reshape( _ )
    axes[i].pcolormesh( _ , _ , predictions, cmap = plt.cm.Paired)
    axes[i].contour( _ , _ , predictions, colors=['k', 'k'], linestyles=['-', '-'], levels=[0, 1])

    axes[i].scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s = 90, facecolors = 'none', edgecolors = 'k')

    axes[i].scatter( _ , _ , c = _ , cmap=plt.cm.Paired, edgecolors='k')
    axes[i].set_axis_off()

plt.show()

# %%
kernels = ['linear', 'poly', 'rbf']

_, axes = plt.subplots(1,3, figsize = (20,5))

# fit the model
for i, kernel in enumerate(kernels):
    #
    clf = svm.SVC(kernel = _ , gamma = 1)
    clf.fit( _ , _ )

    x_min, x_max = _ , _
    y_min, y_max = _ , _

    x_dim, y_dim = np.meshgrid(np.arange( _ , _ , 0.01), np.arange( _ , _ , 0.01))
    predictions = clf.decision_function(np.c_[x_dim.ravel(), y_dim.ravel()])

    predictions = predictions.reshape(x_dim.shape)
    axes[i].pcolormesh( _ , _ , predictions, cmap = plt.cm.coolwarm)
    axes[i].contourf( _ , _ , predictions, alpha = 0.75, cmap = plt.cm.coolwarm)

    axes[i].scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s = 90, facecolors = 'none', edgecolors = 'k')

    axes[i].scatter( _ , _ , c=Y, cmap=plt.cm.coolwarm, edgecolors='k')
    axes[i].set_axis_off()

plt.show()

# %% [markdown]
# Create a function that plots the decision boundaries of a given SVM

# %% [markdown]
# ## In real data

# %% [markdown]
# Evaluate the different SVM kernels in the Iris and Fruits datasets
